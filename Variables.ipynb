# %%
ingresos = 1000
gastos = 400

# %%
ingresos
# Out:
# 1000

# %%
ingresos
gastos
# Out:
# 400

# %%
print(ingresos)
print(gastos)
# Out:
# 1000
# 400

# %%
margen = ingresos-gastos

# %%
print(margen)
# Out:
# 600

# %%
ingresos_text= "Los ingresos han sido altos"
ingresos_alt= "Los ingresos han sido altos"
print(ingresos_text)
print(ingresos_alt)
# Out:
# Los ingresos han sido altos
# Los ingresos han sido altos

# %%
ingresos_text="Los ´ingresos´ han sido altos"

# %%
ingresos_text
# Out:
# 'Los ´ingresos´ han sido altos'

# %%
ingresos=1000
ingresos = 1000
ingresos text= "Los ingresos han sido altos, pero esto da error"
# Out:
#   Cell In[14], line 3
#     ingresos text= "Los ingresos han sido altos, pero esto da error"
#              ^
# SyntaxError: invalid syntax

# %%
ingresos_text = "Los "ingresos" han sido altos"

# %%
gastos = 200

# %%
print(gastos)

# %%
gastos = 100

# %%
beneficios = ingresos - gastos

# %%
print(beneficis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(beneficis)
#
# NameError: name 'beneficis' is not defined

# %%
texto = "Error sin comillas
# Out:
#   Cell In[17], line 1
#     texto = "Error sin comillas
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
2009_ingresos
# Out:
#   Cell In[21], line 1
#     2009_ingresos
#         ^
# SyntaxError: invalid decimal literal

# %%
ingresos_2009 = 25000

# %%
print(ingresos_2009)
# Out:
# 25000

# %%
print(Ingresos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(Ingresos)
#
# NameError: name 'Ingresos' is not defined

# %%
def = 10
# Out:
#   Cell In[31], line 1
#     def = 10
#         ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
help ("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
ingresos = 1000
gastos = 100
beneficios = ingresos - gastos

# %%
print(ingresos)
print(gastos)
print("Los beneficios han sido de:")
print(beneficios)
# Out:
# 1000
# 100
# Los beneficios han sido de:
# 900

# %%
mes = "junio"
print("Los beneficios de %s han sido %s millones" %(mes,beneficios))
# Out:
# Los beneficios de junio han sido 900 millones

# %%
print("Los beneficios de %s han sido %s millones" %(beneficios,mes))
# Out:
# Los beneficios de 900 han sido junio millones

# %%
mes = "agosto"
print("Los beneficios de", mes,"han sido", beneficios,"millones")
# Out:
# Los beneficios de agosto han sido 900 millones

# %%
# Comentario de línea
#print("Esto lo ignora")
print("Esto si lo ejecutara")
# Out:
# Esto si lo ejecutara

# %%
print("Fin del programa") #Esta línea indica que hemos terminado
# Out:
# Fin del programa

# %%
'''
Comentario multilinea
Puedo usar varias lineas sin tener que repetir el #
'''
"""
Los comentarios multilinea pueden ir
entre comillas dobles, y tampoco se ejecutan o interpretan
este
print("No se va a ejecutar")
"""
print("Este print si se va a ejecutar")
# Out:
# Este print si se va a ejecutar

# %%
ventas_jun_jul = ventas_jun + ventas_jul

ventas_jun = 100
ventas_jul = 150
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 ventas_jun_jul = ventas_jun + ventas_jul
#       3 ventas_jun = 100
#       4 ventas_jul = 150
#
# NameError: name 'ventas_jun' is not defined

# %%
ventas_jun
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 ventas_jun
#
# NameError: name 'ventas_jun' is not defined

# %%
ventas_jun = 100
ventas_jul = 150
ventas_jun_jul = ventas_jun + ventas_jul

# %%
print("Las ventas de junio a julio son",ventas_jun_jul)
# Out:
# Las ventas de junio a julio son 250

# %%
altura = 1.80; peso = 75
print(altura, peso)
# Out:
# 1.8 75

# %%
x,y,z = 12, 23, 45

# %%
x = 12
y = 23
z = 45

# %%
altura = 1.85
del altura
print(altura)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 3
#       1 altura = 1.85
#       2 del altura
# ----> 3 print(altura)
#
# NameError: name 'altura' is not defined

# %%
numero = 22
type(numero)
# Out:
# int

# %%
numero_real = 22.0
print(type(numero_real))
# Out:
# <class 'float'>

# %%
numero_real_decimales = 22.45123
type(numero_real_decimales)
# Out:
# float

# %%
print("Sumas y restas")
print(1 + 2)
print(1.0 + 2) #Fijate que cuando sumo un float con int, el resultado es float
print( 1.0 - 2)#Siempre float como tipo de resultado
# Out:
# Sumas y restas
# 3
# 3.0
# -1.0

# %%
print("Mult y div")
print(2 * 2)
print (2.0 * 2)
print(2 / 2)# El tipo de resultado de una división siempre va a ser float y habria que hacer cambio a int.
# Out:
# Mult y div
# 4
# 4.0
# 1.0

# %%
print("Resto División")
print(10/3)
print(int(10/3))
print(10 % 3)
print(10 // 3)
# Out:
# Resto División
# 3.3333333333333335
# 3
# 1
# 3

# %%
n = 434
print("¿Es" ,n, "par?")
resto = n % 2
print("El resto es",resto)
if resto ==0:
    print("Es par")
else:
    print("Es impar")
# Out:
# ¿Es 434 par?
# El resto es 0
# Es par
